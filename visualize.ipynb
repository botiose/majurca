# %% [markdown]
# <h1>Majurca: Model performance visualization</h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_model(model):
    df = pd.read_csv(
        model_dir + "model-" + model + "/history.csv"
    )
    df.name = model
    return df

def display_model(df):
#     yticks = np.arange(df["val_accuracy"].min(), df["val_accuracy"].max(), 
#                        0.001)
    yticks = np.arange(0, 1.05, 0.05)
    
    xticks = np.arange(0, len(df), 10)
    
    df[["accuracy", "val_accuracy"]].plot(grid=True, figsize=(15,8), xticks=xticks, 
                                          yticks=yticks)
    plt.show()
    
    print("accuracy", round(df.iloc[-1]["accuracy"],4))
    print("val_accuracy", round(df.iloc[-1]["val_accuracy"],4))
    
def compare_metric(models, metric):
    plt.figure(figsize=(15,8))
    
    for df in models:
        plt.plot(df[metric], label=df.name)
        plt.legend()
    plt.show()

# %%
model_dir = "/home/otiose/repos/epita/majurca/model/"

# %%
display_model(load_model("01"))
# Out:
# accuracy 1.0
# val_accuracy 0.7571

# %%
display_model(load_model("02"))
# Out:
# accuracy 0.9937
# val_accuracy 0.8857

# %%
display_model(load_model("03"))
# Out:
# accuracy 0.9874
# val_accuracy 0.8286

# %%
display_model(load_model("04"))
# Out:
# accuracy 1.0
# val_accuracy 0.6857

# %%
display_model(load_model("05"))
# Out:
# accuracy 1.0
# val_accuracy 0.7857

# %%
display_model(load_model("06"))
# Out:
# accuracy 0.9921
# val_accuracy 0.6571

# %%
display_model(load_model("07"))
# Out:
# accuracy 1.0
# val_accuracy 0.7571

# %%
display_model(load_model("09"))
# Out:
# accuracy 0.8889
# val_accuracy 0.7

# %% [markdown]
# <h3>Top</h3>

# %%
display_model(load_model("10"))
# Out:
# accuracy 1.0
# val_accuracy 0.8209

# %% [markdown]
# <h3>Side Horizontal: 32 : 100</h3>

# %%
display_model(load_model("11"))
# Out:
# accuracy 0.998
# val_accuracy 0.8519

# %% [markdown]
# <h3>Side Vertical: ? : 100</h3>

# %%
display_model(load_model("12"))
# Out:
# accuracy 1.0
# val_accuracy 0.8143

# %% [markdown]
# <h3>Side Horizontal: 32 : Full</h3>

# %%
display_model(load_model("13"))
# Out:
# accuracy 1.0
# val_accuracy 0.863

# %% [markdown]
# <h3>Side Horizontal : 32K : 100 </h3>

# %%
display_model(load_model("14"))
# Out:
# accuracy 0.981
# val_accuracy 0.8143

# %% [markdown]
# <h3>Side Horizontal : 32[IGH] : full</h3>

# %%
display_model(load_model("15"))
# Out:
# accuracy 1.0
# val_accuracy 0.8889

# %% [markdown]
# <h3>Top: 200</h3>

# %%
display_model(load_model("17"))
# Out:
# accuracy 1.0
# val_accuracy 0.9

# %% [markdown]
# <h3>Side</h3>

# %%
display_model(load_model("18"))
# Out:
# accuracy 1.0
# val_accuracy 0.6857

# %% [markdown]
# <h3>Side cropped</h3>

# %%
display_model(load_model("19"))
# Out:
# accuracy 0.9992
# val_accuracy 0.7143

# %% [markdown]
# <h3>Side: white light search</h3>

# %%
display_model(load_model("20"))
# Out:
# accuracy 1.0
# val_accuracy 0.8357

# %% [markdown]
# <h3>Top: full</h3>

# %%
display_model(load_model("21"))
# Out:
# accuracy 1.0
# val_accuracy 0.9218

# %%
df01 = load_model("19")
df02 = load_model("20")
model_df = [df01, df02]

# %% [markdown]
# <h2>Training accuracy comparision</h2>

# %%
compare_metric(model_df, "accuracy")

# %% [markdown]
# <h2>Validation accuracy comparison</h2>

# %%
compare_metric(model_df, "val_accuracy")
