# %% [markdown]
# <a href="https://colab.research.google.com/github/christopherdiamana/majurca/blob/develop/load_new_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install azure-storage-file-share

# %%
from azure.core.exceptions import (
    ResourceExistsError,
    ResourceNotFoundError
)

from azure.storage.fileshare import (
    ShareServiceClient,
    ShareClient,
    ShareDirectoryClient,
    ShareFileClient
)

# %%
connection_string = "BlobEndpoint=https://majurca.blob.core.windows.net/;QueueEndpoint=https://majurca.queue.core.windows.net/;FileEndpoint=https://majurca.file.core.windows.net/;TableEndpoint=https://majurca.table.core.windows.net/;SharedAccessSignature=sv=2020-08-04&ss=bfqt&srt=sco&sp=rwdlacupitfx&se=2022-12-06T16:59:15Z&st=2021-12-06T08:59:15Z&spr=https&sig=zRIhKzpgg6Y9jw3tNDnPK7oz9O2aCER6rJ5lKVjatVU%3D"

# %%
# Create a ShareServiceClient from a connection string
service_client = ShareServiceClient.from_connection_string(connection_string)

# %% [markdown]
# ---

# %% [markdown]
# From here I started some tests

# %%
service_client.account_name
# Out:
# 'majurca'

# %%
majurca_list_shares = service_client.list_shares()

# %%
for i, r in enumerate(majurca_list_shares):
   print(r)
# Out:
# {'name': 'datasets', 'last_modified': datetime.datetime(2019, 2, 26, 17, 9, 6, tzinfo=datetime.timezone.utc), 'etag': '"0x8D69C0D1DC10738"', 'quota': 5120, 'access_tier': 'TransactionOptimized', 'next_allowed_quota_downgrade_time': None, 'metadata': None, 'snapshot': None, 'deleted': None, 'deleted_time': None, 'version': None, 'remaining_retention_days': None, 'provisioned_egress_mbps': None, 'provisioned_ingress_mbps': None, 'provisioned_iops': None, 'lease': {'status': 'unlocked', 'state': 'available', 'duration': None}, 'protocols': None, 'root_squash': None}

# %%
share_name = "datasets"

# %%
majurca_share_client = ShareClient.from_connection_string(connection_string, share_name)

# %%
majurca_share_client.account_name
# Out:
# 'majurca'

# %%
majurca_share_client.share_name
# Out:
# 'datasets'

# %%
majurca_list_directories_and_files = majurca_share_client.list_directories_and_files()

# %%
for i, r in enumerate(majurca_list_directories_and_files):
   print(r)
# Out:
# {'name': 'acquisitions', 'last_modified': None, 'etag': None, 'server_encrypted': None, 'metadata': None, 'change_time': None, 'creation_time': None, 'last_write_time': None, 'last_access_time': None, 'file_attributes': None, 'permission_key': None, 'file_id': '13835132822072852480', 'parent_id': None, 'is_directory': True}
# {'name': 'Majurca_focale_test', 'last_modified': None, 'etag': None, 'server_encrypted': None, 'metadata': None, 'change_time': None, 'creation_time': None, 'last_write_time': None, 'last_access_time': None, 'file_attributes': None, 'permission_key': None, 'file_id': '13835084443561230336', 'parent_id': None, 'is_directory': True}

# %%
for i, r in enumerate(majurca_share_client.list_directories_and_files('Majurca_focale_test')):
   print(r)
# Out:
# {'name': '12mm', 'last_modified': None, 'etag': None, 'server_encrypted': None, 'metadata': None, 'change_time': None, 'creation_time': None, 'last_write_time': None, 'last_access_time': None, 'file_attributes': None, 'permission_key': None, 'file_id': '11529241434347536384', 'parent_id': None, 'is_directory': True}
# {'name': '25mm', 'last_modified': None, 'etag': None, 'server_encrypted': None, 'metadata': None, 'change_time': None, 'creation_time': None, 'last_write_time': None, 'last_access_time': None, 'file_attributes': None, 'permission_key': None, 'file_id': '16140927452774924288', 'parent_id': None, 'is_directory': True}
# ...

# %% [markdown]
# ---

# %%
def list_files_and_dirs(self, connection_string, share_name, dir_name):
    try:
        # Create a ShareClient from a connection string
        share_client = ShareClient.from_connection_string(
            connection_string, share_name)
        
        file_counter = 0
        directory_counter = 0

        for item in list(share_client.list_directories_and_files(dir_name)):
            if item["is_directory"]:
                print("Directory:", item["name"])
                directory_counter += 1
            else:
                print("File:", dir_name + "/" + item["name"])
                file_counter += 1

        print("Nomber of Directory", directory_counter)
        print("Nomber of File", file_counter)

        
    except ResourceNotFoundError as ex:
        print("ResourceNotFoundError:", ex.message)

# %%
share_name = "datasets"

# %%
dir_name = "acquisitions"

# %%
list_files_and_dirs(service_client, connection_string, share_name, dir_name)
# Out:
# Streaming output truncated to the last 5000 lines.
# File: acquisitions/2021-11-14-11-32-24-759514-CAM192-168-0-31H.png
# File: acquisitions/2021-11-14-11-32-24-982792-CAM192-168-0-32K.png
# File: acquisitions/2021-11-14-11-32-37-716394-CAM192-168-0-31H.png
# File: acquisitions/2021-11-14-11-32-37-944155-CAM192-168-0-32K.png
# File: acquisitions/2021-11-14-11-33-00-371153-CAM192-168-0-31H.png
# File: acquisitions/2021-11-14-11-33-00-597982-CAM192-168-0-32K.png
# File: acquisitions/2021-11-14-11-33-15-499494-CAM192-168-0-31H.png
# File: acquisitions/2021-11-14-11-33-15-727416-CAM192-168-0-32K.png
# File: acquisitions/2021-11-14-11-33-25-490799-CAM192-168-0-31H.png
# File: acquisitions/2021-11-14-11-33-25-718185-CAM192-168-0-32K.png
# File: acquisitions/2021-11-14-11-33-41-276739-CAM192-168-0-31H.png
# File: acquisitions/2021-11-14-11-33-41-504061-CAM192-168-0-32K.png
# File: acquisitions/2021-11-14-11-33-51-421393-CAM192-168-0-31H.png
# ...
